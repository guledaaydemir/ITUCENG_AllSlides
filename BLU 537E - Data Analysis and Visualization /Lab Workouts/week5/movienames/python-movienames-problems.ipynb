# %% [markdown]
# # Analysis on movie names

# %% [markdown]
# GroupLens Research has collected and made available rating data sets from the MovieLens web site (https://grouplens.org/datasets/movielens/).
# <br>The data sets were collected over various periods of time, depending on the size of the set.
# <br>MovieLens 1M Dataset: collected from users of MovieLens in the late 1990s and early 2000s.
# <br>1 million ratings from 6000 users on 4000 movies.
# <br>It’s spread across 3 tables: ratings, user information, and movie information.
# You can find users.dat, movies.dat, ratings.dat file in the ml-1m folder.

# %% [markdown]
# In this example we will work only on movies.dat file

# %% [markdown]
# ## Task: modify movies.dat file so that year information embedded in the title column is written as a separate column.

# %% [markdown]
# ![Screen%20Shot%202020-11-16%20at%2016.33.17.png](attachment:Screen%20Shot%202020-11-16%20at%2016.33.17.png)

# %% [markdown]
# First read movies.dat file

# %%
moviefilename="movies.dat"
movies=open(moviefilename).readlines()

# %% [markdown]
# • Normally when reading a file you don’t have to specify encoding explicity.
# <br>• However in our case there was a character which was not understood by the standart “utf-8” format.

# %% [markdown]
# try reading with encoding latin-1

# %%
moviefilename="movies.dat"
movies=open(moviefilename,encoding="latin-1").readlines()

# %% [markdown]
# check how many lines you have

# %% [markdown]
# using regular expression we will find the year information from the movie title

# %% [markdown]
# get the movie title of the first movie

# %%
title=

# %%
title

# %% [markdown]
# write a pattern to catch the year information

# %%
pattern=

# %%
import re
re.findall(pattern,title)

# %% [markdown]
# now extract year information from the title of each movie and write a new file called movies-modified.data

# %%
import re
pattern=
outputfilename="movies-modified.dat"
# create a writeable file
outputfile=
# write modified file

# %% [markdown]
# ## Task: Find the year that has highest number of movies in movies-modified.dat file.

# %% [markdown]
# First read the file and create a list for year information

# %%
# create a year list and add year information for each movie
moviefilename="movies-modified.dat"
moviefile=open(moviefilename)
movies=moviefile.readlines()
yearlist=[]

# %%
yearlist

# %% [markdown]
# in this yearlist, we should calculate the frequency of each year

# %%
# use counter from the collections module

# %% [markdown]
# print the top-10 years having the highest number of movies

# %% [markdown]
# ## Task: Find the frequency of each genre type and print top-10 most frequent ones

# %% [markdown]
# • we will do similar operation for movie genres.
# <br>• Note that movie genres are separated by “|” character.

# %% [markdown]
# First read genres into a genrelist

# %%
moviefilename="movies-modified.dat"
moviefile=open(moviefilename)
movies=moviefile.readlines()
genrelist=[]

# %% [markdown]
# Now calculate the frequency

# %%
# format the oputput such that: 15 characters for the genre and 5 characters for frequency
# example outputline:
# Drama          : 1603
# for formatting try using f-string
