# %% [markdown]
# ## Print Function

# %% [markdown]
# • In Python, print function prints things to the standard output stream
# <br>• The print function requires parenthesis around its arguments
# <br>• Anything inside quotes will (with a few exceptions) be printed exactly as it appears.
# <br>• print(value1, ..., sep=' ', end='\n', file=sys.stdout, flush=False)

# %%
k=30

# %%
print(k)

# %%
print("I have",k,"books")

# %%
print("I have",k,"books",sep=",")

# %%
print("I have",k,"books",sep="")

# %%
print("I have",k,"books",sep="::")

# %% [markdown]
# end is a string added at the end of the printed text, which defaults to a \n newline character

# %%
print("on the first line")
print("on the second line")

# %%
print("on the first line",end="")
print("on the second line")

# %% [markdown]
# file specifies the file, standard stream, or other file-like object to which the text will be sent;

# %%
x="spam"
y=99
z="eggs"

# %%
print(x,y,z,file=open("data.txt","w"))

# %% [markdown]
# go and check the content of data.txt file

# %% [markdown]
# ## Variable Names

# %% [markdown]
# • Variable names can contain letters, numbers, and the underscore.
# <br>• Variable names cannot contain spaces.
# <br>• Variable names cannot start with a number.
# <br>• Case matters—for instance, temp and Temp are different.
# <br>• Syntax: (underscore or letter) + (any number of letters, digits, or underscores)
# <br>• Reserved words cannot be used as variable names.

# %%
student_grade=40

# %%
student grade=40

# %%
6student_grade=40

# %% [markdown]
# <div>
# <img src="attachment:Screen%20Shot%202021-04-28%20at%2018.04.47.png" width="600" height="300" >
# <div>

# %%
for=4

# %%
class=4

# %% [markdown]
# ## Math Operators

# %% [markdown]
# Operators are special symbols that represent computations like addition and multiplication

# %% [markdown]
# <div>
# <img src="attachment:Screen%20Shot%202021-04-28%20at%2018.08.30.png" width="450" height="200" >

# %%
3+4

# %%
5-2.5

# %%
2*4

# %%
2**4

# %%
4/5

# %% [markdown]
# The integer division operator // this operator always truncates fractional remainders down to their floor, regardless of types

# %%
13/4

# %%
13//4

# %% [markdown]
# The modulo operator, %, returns the remainder from a division.

# %%
15%4

# %%
12%4

# %% [markdown]
# ## Math module

# %%
import math

# %%
math.sqrt(4)

# %%
math.log10(10)

# %%
dir(math)

# %% [markdown]
# # If statements

# %%
x=1
if x<3:
    print(x,"is less than",3)
else:
    print(x,"is greater than",3)

# %% [markdown]
# run above script with x=4

# %%
x=4
y=5
if x>y:
    print(x,"is greater than",y)
elif x<y:
    print(x,"is less than",y)
else:
    print(x,"is equal to",y)

# %% [markdown]
# using and or operators you can test more than one question

# %%
points=80
if points>=85:
    print("the grade is A")
elif points>=70 and points<85:
    print("the grade is B")
elif points>=60 and points<70:
    print("the grade is C")
elif points>=45 and points<60:
    print("the grade is D")
else:
    print("the grade is F")

# %% [markdown]
# # For loops

# %% [markdown]
# The for loop is a generic iterator in Python: it can step through the items in any ordered sequence or other iterable object.

# %%
for i in range(10):
    print(i)

# %%
k=["jacke","john","marry","jessie"]

# %% [markdown]
# print the names in this list

# %%
for i in range(0,len(k)):
    print(k[i])

# %% [markdown]
# in python you don't need indeces you can directly assign elements into iteration variable

# %%
for x in k:
    print(x)

# %% [markdown]
# ## Range Function

# %% [markdown]
# Range it returns an iterable that generates numbers in the range on demand, instead of building the result list in memory.
# <br>• You must use list(range(...)) to force an actual range list if one is needed

# %%
range(5,10)

# %%
list(range(5,10))

# %% [markdown]
# ## For loop example

# %% [markdown]
# • Creating a monthly duty schedule

# %%
namelist=["Ahmet","Ali","Ayşe","Gökhan","Zeynep","Fatih"]

# %%
for i in range(1,31):
    if i%6 == 1:
        print(i,"ocak ",namelist[0])
    elif i%6 == 2:
        print(i,"ocak ",namelist[1])
    elif i%6 == 3:
        print(i,"ocak ",namelist[2])
    elif i%6 == 4:
        print(i,"ocak ",namelist[3])
    elif i%6 == 5:
        print(i,"ocak ",namelist[4])   
    elif i%6 == 0:    
        print(i,"ocak ",namelist[5])

# %% [markdown]
# we can do the same using dictionary

# %%
namelist={1:"Ahmet",2:"Ali",3:"Ayşe",4:"Gökhan",5:"Zeynep",0:"Fatih"}
for i in range(1,31):
    x=i%6
    print(i,"ocak",namelist[x])

# %% [markdown]
# ## A for loop can iterate any kind of sequence object

# %%
s="python for data analysis"

# %%
for t in s:
    print(t)

# %% [markdown]
# ## Iterating over a Dictionary

# %%
D={"a":1,"b":2,"c":3}
for x in D:
    print(x)

# %%
D={"a":1,"b":2,"c":3}
for x,y in D.items():
    print(x,y)

# %%
salary={"John":5000,"Marry":5500,"Harry":4500,"Eva":4000}

# %% [markdown]
# let's calculate %10 salary increase for all the people

# %%
for x,y in salary.items():
    salary[x]=y+y*0.1

# %%
salary

# %% [markdown]
# # While loops

# %% [markdown]
# A while loop repeatedly executes a block of statements as long as a test at the top keeps evaluating to a true value.

# %%
x=0
x<10

# %%
while x<10:
    y=x**2
    print(y)
    x=x+1

# %%
x<10

# %% [markdown]
# ## While loop example:
# A script that will ends the while loop if the randomly generated integer is 45.

# %%
import random
x=0
counter=0
while x != 45:
    x=random.randint(0,100)
    counter = counter + 1
    
print("the number of iteration is ",counter)
print("the last x number generated is",x)

# %% [markdown]
# ## break, continue and pass

# %% [markdown]
# 1. break : Jumps out of the closest enclosing loop (past the entire loop statement)
# 2. Continue: Jumps to the top of the closest enclosing loop (to the loop’s header line)
# 3. pass : Does nothing at all: it’s an empty statement placeholder

# %%
x=4
if x<0:
    print(x,"is a negative number")
elif x==0:
    # no operation
    pass
else:
    print(x,"is a positive number")

# %% [markdown]
# remove the pass from the above script and run again

# %%
#continue example
x=10
while x>=0:
    x=x-1
    if x%2 !=0:
        continue
    print(x)

# %%
mylist=[2,5,8]

for i in range(10):
    if i in mylist:
        continue
    x=i**2
    print("square of",i," is",x)

# %%
#break example
namelist=["Ahmet","Ali","Ayşe","Gökhan","Zeynep","Fatih"]
for name in namelist:
    if name=="Gökhan":
        break
    else:
        print(name)

# %% [markdown]
# # List Comprehensions

# %% [markdown]
# Python supports a concept called "list comprehensions".
# <br> It can be used to construct lists in a very natural, easy way, like a mathematician is used to do.

# %%
l=[1,2,3,4,5]

# %% [markdown]
# let's add 10 to each element

# %%
for i in range(0,len(l)):
    l[i]=l[i]+10

# %%
l

# %% [markdown]
# we can do the same using list comprehension

# %%
l=[1,2,3,4,5]

# %%
l=[x+10 for x in l ]

# %%
l

# %%
mylist=list(range(10));mylist

# %%
newlist=[a**2 for a in mylist]

# %%
newlist

# %% [markdown]
# ## List Comprehensions: Example

# %% [markdown]
# Counting the numbers in a list that is greater than 50

# %% [markdown]
# using list comprehension create a list of 300 random numbers which should be between 0 and 100

# %%
l=

# %% [markdown]
# double check the count of numbers in the list "l"

# %% [markdown]
# now count how many numbers are greater than 50

# %% [markdown]
# # Exercise

# %% [markdown]
# Create a 10 x10 list of numbers. Then write a program that creates a dictionary whose keys are the numbers and whose values are the how many times the number occurs. Then print the three most common numbers.

# %% [markdown]
# First create a two dimensional list that contains random numbers between 1 and 10

# %% [markdown]
# Now, count the the occurrences of each number using a dictionary.

# %% [markdown]
# Sorting based on the occurrences of numbers and printing the three most common numbers.

# %% [markdown]
# ### we do also have dictionary comprehensions

# %%
DIAL_CODES = [
... (86, 'China'),
... (91, 'India'),
... (1, 'United States'),
... (62, 'Indonesia'),
... (55, 'Brazil'),
... (92, 'Pakistan'),
... (880, 'Bangladesh'),
... (234, 'Nigeria'),
... (7, 'Russia'),
... (81, 'Japan'),
... ]

# %%
DIAL_CODES

# %%
country_code = {country: code for code, country in DIAL_CODES}

# %%
country_code

# %% [markdown]
# # Functions

# %% [markdown]
# • Functions are declared using the def keyword and returned from using the return keyword:
# <br>• def creates a function object and assigns it to a name

# %%
def numbercheck(x):
    if x%2==0:
        print(x,"is an even number")
    else:
        print(x,"is an odd number")

# %%
numbercheck(3)

# %% [markdown]
# • You can pass more than one value to a function

# %%
def numbercompare(x,y):
    if x==y:
        print(x,"is equal to ",y)
    elif x<y:
        print(x,"is less than",y)
    else:
        print(x,"is greater than",y)

# %%
numbercompare(4,5)

# %% [markdown]
# • Each function can have some number of positional arguments and some number of keyword arguments
# <br>• Keyword arguments are most commonly used to specify default values or optional arguments
# <br>• x and y are positional arguments while z is a keyword argument
# <br>• The main restriction on function arguments it that the keyword arguments must follow the positional arguments (if any)

# %%
def my_function(x,y,z=1.5):
    if z>1:
        return z*(x+y)
    else:
        return z/(x+y)

# %%
my_function(5,6)

# %%
my_function(5,6,z=9)

# %% [markdown]
# <br>• Return kewyord gives only the output of the function
# <br>• Other variables created inside the function will be deleted after the function completes its task

# %%
def f():
    x1=5
    x2=6
    x3=7
    return x1,x2

# %%
a,b=f()

# %%
a

# %%
x1

# %% [markdown]
# # Lambda Functions

# %% [markdown]
# • Python has support for so-called anonymous or lambda functions
# <br>• These are simple functions consisting of a single statement, the result of which is the return value.

# %%
def f1(x):
    return x**2

# %%
f1(4)

# %%
f2=lambda x: x**2

# %%
f2(4)

# %%
type(f2)

# %% [markdown]
# ## Modifying a List in a Function

# %% [markdown]
# - When you pass a list to a function, the function can modify the list.
# - Any changes made to the list inside the function’s body are permanent, allowing you to work efficiently even when you’re dealing with large amounts of data.

# %%
x=[3,4,5]

# %%
# lets write a function that takes a list as the input and removes the first element
def f(a):
    a.pop(0)
    return a

# %%
f(x)

# %% [markdown]
# let's see if x is changed or not

# %%
x

# %% [markdown]
# - Advantage: we can pass large objects around our programs without making multiple copies along the way, and we can easily update these objects as we go

# %% [markdown]
# ## How can we avoid change of mutable objects?

# %%
x=[3,4,5]

# %%
f(x[:])

# %% [markdown]
# x[:] copies the object

# %%
x

# %% [markdown]
# ## Passing an arbitrary number of arguments

# %% [markdown]
# Sometimes you won’t know ahead of time how many arguments a function needs to accept. Fortunately, Python allows a function to collect an arbitrary number of arguments from the calling statement.

# %%
def make_pizza(*toppings):
    """Print the list of toppings that have been requested."""
    print(toppings)
make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')

# %% [markdown]
# - The asterisk in the parameter name *toppings tells Python to make an empty tuple called toppings and pack whatever values it receives into this tuple.

# %% [markdown]
# ## Using Arbitrary Keyword Arguments

# %%
def build_profile(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last
    for key, value in user_info.items():
        profile[key] = value
    return profile

# %%
user_profile = build_profile('albert', 'einstein',
                             location='princeton',
                             field='physics')
print(user_profile)

# %% [markdown]
# - The double asterisks before the parameter **user_info cause Python to create an empty dictionary called user_info and pack whatever name-value pairs it receives into this dictionary.

# %% [markdown]
# ## Calls: Unpacking arguments

# %% [markdown]
# - we can use the * syntax when we call a function, too. In this context, its meaning is the inverse of its meaning in the function definition—it unpacks a collection of arguments, rather than building a collection of arguments

# %%
def func(a, b, c, d): 
    print(a, b, c, d)

# %%
args = (1, 2) + (3, 4)

# %%
args

# %%
func(args)

# %%
func(*args)

# %%
args = {'a': 1, 'b': 2, 'c': 3, "d":4}

# %%
args

# %%
func(args)

# %%
func(**args)

# %% [markdown]
# - don’t confuse the */** starred-argument syntax in the function header and the function call
# - in the header it collects any number of arguments, while in the call it unpacks any number of arguments.
# - In both, one star means positionals, and two applies to keywords.

# %% [markdown]
# # The LEGB Rule in NameSpace

# %% [markdown]
# variables are searched in the name in the following order:
# - local,Enclosed, Global, Built-in

# %%
a="test"
def function1():
    print("a in function1",a)

# %%
function1()

# %%
a="test"
def function1():
    a=[1,2,4]
    print("a in function1",a)

# %%
function1()

# %%
a="test"
def function1():
    a=[1,2,4]
    print("a in function1",a)
    def function2():
        print("a in function2",a)
    function2()

# %%
function1()

# %%
a="test"
def function1():
    a=[1,2,4]
    print("a in function1",a)
    def function2():
        a=100.0
        print("a in function2",a)
    function2()

function1()
print("a in outside functions",a)

# %% [markdown]
# ### assigning variales as global inside functions

# %%
a="test"
def function1():
    a=[1,2,4]
    print("a in function1",a)
    def function2():
        global a
        a=100.0
        print("a in function2",a)
    function2()

function1()
print("a in outside functions",a)

# %% [markdown]
# ### How to access built-in scope

# %%
import builtins
dir(builtins)

# %% [markdown]
# ### a small example related to scopes

# %%
list("abcd")

# %%
list=10

# %%
list("abcd")
