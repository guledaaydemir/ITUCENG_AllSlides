# %% [markdown]
# # Weather 2012 Data set

# %% [markdown]
# We have hourly data for the weather conditions for one year
# <br> we will perform some analysis on this data

# %%
#first import pandas
import pandas as pd

# %% [markdown]
# this is how the data looks like in weather_2012.csv file

# %% [markdown]
# ![Screen%20Shot%202018-10-16%20at%2014.51.03.png](attachment:Screen%20Shot%202018-10-16%20at%2014.51.03.png)

# %% [markdown]
# Read the data from the file into a dataframe object

# %%
data=pd.read_csv("weather_2012.csv",skiprows=1,header=None,
  names=["DateTime","Temp","DewPointTemp",
         "RelHum","WindSpeed","Visibility","StnPress" ,"Weather"])

# %% [markdown]
# See the top of the dataframe

# %%
data.head()
# Out:
#               DateTime  Temp  DewPointTemp  RelHum  WindSpeed  Visibility  \
# 0  2012-01-01 00:00:00  -1.8          -3.9      86          4         8.0
# 1  2012-01-01 01:00:00  -1.8          -3.7      87          4         8.0
# 2  2012-01-01 02:00:00  -1.8          -3.4      89          7         4.0
# 3  2012-01-01 03:00:00  -1.5          -3.2      88          6         4.0
# 4  2012-01-01 04:00:00  -1.5          -3.3      88          7         4.8
#
#    StnPress               Weather
# 0    101.24                   Fog
# 1    101.24                   Fog
# 2    101.26  Freezing Drizzle,Fog
# 3    101.27  Freezing Drizzle,Fog
# 4    101.23                   Fog

# %% [markdown]
# Assing the data type of DateTime column as datetime objects

# %%
data.DateTime=

# %%
data.DateTime.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Set this DateTime column as the index of the data frame

# %%
data=

# %% [markdown]
# Check the top of the dataframe

# %%
data.head()
# Out:
#                      Temp  DewPointTemp  RelHum  WindSpeed  Visibility  \
# DateTime
# 2012-01-01 00:00:00  -1.8          -3.9      86          4         8.0
# 2012-01-01 01:00:00  -1.8          -3.7      87          4         8.0
# 2012-01-01 02:00:00  -1.8          -3.4      89          7         4.0
# 2012-01-01 03:00:00  -1.5          -3.2      88          6         4.0
# 2012-01-01 04:00:00  -1.5          -3.3      88          7         4.8
#
#                      StnPress               Weather
# DateTime
# 2012-01-01 00:00:00    101.24                   Fog
# 2012-01-01 01:00:00    101.24                   Fog
# 2012-01-01 02:00:00    101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00    101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00    101.23                   Fog

# %% [markdown]
# Calculate daily min,average and max temperatures.

# %%
daily_temp=data

# %% [markdown]
# check the top of the data frame

# %%
daily_temp.head()
# Out:
#              min       mean  max
# DateTime
# 2012-01-01  -1.8   0.629167  5.3
# 2012-01-02  -7.4   0.041667  5.2
# 2012-01-03 -17.3 -14.416667 -9.0
# 2012-01-04 -18.6 -13.645833 -7.6
# 2012-01-05  -9.9  -6.750000 -4.1

# %% [markdown]
# Plot this data

# %%
daily_temp.plot()

# %% [markdown]
# Suppose, we would like to analyze how visibility changes during the day in a particular month
# <br> to do this, calculate the average visibility over the days for each hour

# %% [markdown]
# since index is a time object we can get hour and month information from the index

# %%
data["hour"]=
data["month"]=
data.head()
# Out:
#                      Temp  DewPointTemp  RelHum  WindSpeed  Visibility  \
# DateTime
# 2012-01-01 00:00:00  -1.8          -3.9      86          4         8.0
# 2012-01-01 01:00:00  -1.8          -3.7      87          4         8.0
# 2012-01-01 02:00:00  -1.8          -3.4      89          7         4.0
# 2012-01-01 03:00:00  -1.5          -3.2      88          6         4.0
# 2012-01-01 04:00:00  -1.5          -3.3      88          7         4.8
#
#                      StnPress               Weather  hour  month
# DateTime
# 2012-01-01 00:00:00    101.24                   Fog     0      1
# 2012-01-01 01:00:00    101.24                   Fog     1      1
# 2012-01-01 02:00:00    101.26  Freezing Drizzle,Fog     2      1
# 2012-01-01 03:00:00    101.27  Freezing Drizzle,Fog     3      1
# 2012-01-01 04:00:00    101.23                   Fog     4      1

# %% [markdown]
# Now, we can use groupby function to group data on months and hours

# %%
visdata=data

# %%
visdata.head()
# Out:
# month  hour
# 1      0       20.858065
#        1       21.716129
#        2       20.416129
#        3       20.309677
#        4       19.916129
# Name: Visibility, dtype: float64

# %% [markdown]
# Get the result for january

# %%
visdata
# Out:
# hour
# 0     20.858065
# 1     21.716129
# 2     20.416129
# 3     20.309677
# 4     19.916129
# 5     19.996774
# 6     19.548387
# 7     20.203226
# 8     22.254839
# 9     24.693548
# 10    24.254839
# 11    25.200000
# 12    25.225806
# 13    25.161290
# 14    26.580645
# 15    26.122581
# 16    24.887097
# 17    22.764516
# 18    19.309677
# 19    19.641935
# 20    19.983871
# 21    20.100000
# 22    21.300000
# 23    19.961290
# Name: Visibility, dtype: float64

# %% [markdown]
# Get the result from january to march only for hours between 10 to 16

# %%
visdata
# Out:
# month  hour
# 1      10      24.254839
#        11      25.200000
#        12      25.225806
#        13      25.161290
#        14      26.580645
#        15      26.122581
#        16      24.887097
# 2      10      29.368966
#        11      30.775862
#        12      31.527586
#        13      31.375862
#        14      30.582759
#        15      31.275862
#        16      31.168966
# 3      10      28.512903
#        11      29.674194
#        12      32.677419
#        13      33.158065
#        14      32.996774
#        15      32.648387
#        16      33.587097
# Name: Visibility, dtype: float64

# %% [markdown]
# Let's plot the data for january and july

# %%
visdata.
visdata.

# %% [markdown]
# ## Plot in a bar chart total hours for rain,fog and clear weather

# %% [markdown]
# let's remember our data again

# %%
data.head()
# Out:
#                      Temp  DewPointTemp  RelHum  WindSpeed  Visibility  \
# DateTime
# 2012-01-01 00:00:00  -1.8          -3.9      86          4         8.0
# 2012-01-01 01:00:00  -1.8          -3.7      87          4         8.0
# 2012-01-01 02:00:00  -1.8          -3.4      89          7         4.0
# 2012-01-01 03:00:00  -1.5          -3.2      88          6         4.0
# 2012-01-01 04:00:00  -1.5          -3.3      88          7         4.8
#
#                      StnPress               Weather  hour  month
# DateTime
# 2012-01-01 00:00:00    101.24                   Fog     0      1
# 2012-01-01 01:00:00    101.24                   Fog     1      1
# 2012-01-01 02:00:00    101.26  Freezing Drizzle,Fog     2      1
# 2012-01-01 03:00:00    101.27  Freezing Drizzle,Fog     3      1
# 2012-01-01 04:00:00    101.23                   Fog     4      1

# %% [markdown]
# Get all the rows that contain "fog" in the weather column
# <br> create new dataframe called fogdata

# %%
fogdata=

# %%
fogdata.head()
# Out:
#                      Temp  DewPointTemp  RelHum  WindSpeed  Visibility  \
# DateTime
# 2012-01-01 00:00:00  -1.8          -3.9      86          4         8.0
# 2012-01-01 01:00:00  -1.8          -3.7      87          4         8.0
# 2012-01-01 02:00:00  -1.8          -3.4      89          7         4.0
# 2012-01-01 03:00:00  -1.5          -3.2      88          6         4.0
# 2012-01-01 04:00:00  -1.5          -3.3      88          7         4.8
#
#                      StnPress               Weather  hour  month
# DateTime
# 2012-01-01 00:00:00    101.24                   Fog     0      1
# 2012-01-01 01:00:00    101.24                   Fog     1      1
# 2012-01-01 02:00:00    101.26  Freezing Drizzle,Fog     2      1
# 2012-01-01 03:00:00    101.27  Freezing Drizzle,Fog     3      1
# 2012-01-01 04:00:00    101.23                   Fog     4      1

# %%
fogdata.tail()
# Out:
#                      Temp  DewPointTemp  RelHum  WindSpeed  Visibility  \
# DateTime
# 2012-12-30 03:00:00  -9.1         -10.4      90         11         3.6
# 2012-12-30 04:00:00  -9.3         -10.6      90         13         9.7
# 2012-12-30 05:00:00  -9.1         -10.4      90         11         4.0
# 2012-12-30 06:00:00  -9.3         -10.8      89         17         8.0
# 2012-12-31 10:00:00  -7.4          -8.9      89          4         6.4
#
#                      StnPress   Weather  hour  month
# DateTime
# 2012-12-30 03:00:00    100.30  Snow,Fog     3     12
# 2012-12-30 04:00:00    100.28  Snow,Fog     4     12
# 2012-12-30 05:00:00    100.32  Snow,Fog     5     12
# 2012-12-30 06:00:00    100.39  Snow,Fog     6     12
# 2012-12-31 10:00:00    101.05  Snow,Fog    10     12

# %% [markdown]
# Now, calculate total number of hours in each month for "fog" weather

# %%
monthly_foghours=fogdata.

# %%
monthly_foghours.head()
# Out:
# DateTime
# 2012-01-31    34
# 2012-02-29    14
# 2012-03-31    67
# 2012-04-30    11
# 2012-05-31    54
# Freq: M, dtype: int64

# %% [markdown]
# Do the same calculation for "Clean" and "Rain" weathers

# %%
cleardata=
monthly_clearhours=
monthly_clearhours.head()
# Out:
# DateTime
# 2012-01-31    194
# 2012-02-29    247
# 2012-03-31    292
# 2012-04-30    211
# 2012-05-31    298
# Freq: M, dtype: int64

# %%
raindata=data
monthly_rainhours=
monthly_rainhours.head()
# Out:
# DateTime
# 2012-01-31    29
# 2012-02-29    32
# 2012-03-31    46
# 2012-04-30    94
# 2012-05-31    77
# Freq: M, dtype: int64

# %% [markdown]
# We have three series , we will make a dataframe from these series using pd.concat function
# <br> before doing that, we will name our series

# %%
monthly_foghours
monthly_rainhours
monthly_clearhours

# %% [markdown]
# check monthly_rainhours again

# %%
monthly_rainhours.head()
# Out:
# DateTime
# 2012-01-31    29
# 2012-02-29    32
# 2012-03-31    46
# 2012-04-30    94
# 2012-05-31    77
# Freq: M, Name: Rain, dtype: int64

# %% [markdown]
# now create a dataframe called "result"

# %%
result

# %%
result.head()
# Out:
#             Clear  Fog  Rain
# DateTime
# 2012-01-31    194   34    29
# 2012-02-29    247   14    32
# 2012-03-31    292   67    46
# 2012-04-30    211   11    94
# 2012-05-31    298   54    77

# %%
result.plot.bar()

# %% [markdown]
# x axis does not look very nice!
# <br> change index into a different format

# %%
result.index= #changing index to month names

# %%
result.head()
# Out:
#           Clear  Fog  Rain
# January     194   34    29
# February    247   14    32
# March       292   67    46
# April       211   11    94
# May         298   54    77

# %%
result.plot.bar(rot=45)
